# %% [markdown]
# # EDA: Componente de Texto (Clinical Reports)
#
# This notebook is autogenerated as a boilerplate for Data Exploration (EDA).

# %%
import sys
import os
from pathlib import Path
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    repo_root = '/content/clinical_core'
else:
    repo_root = os.path.abspath(os.path.join(os.getcwd(), '../../../../..'))
sys.path.append(os.path.join(repo_root, 'code'))
print('✅ Entorno EDA de Texto Configurado.')

# %%
import xml.etree.ElementTree as ET
import collections
import matplotlib.pyplot as plt
import re

# %%
# CARGA Y PARSEO XML (Clinical Supplements / Pathology Reports)
# xml_path = '/content/drive/MyDrive/data_tesis/clinicalsupplement/ejemplo.xml'
# tree = ET.parse(xml_path)
# root = tree.getroot()
# print('Namespace raíz:', root.tag)

# %%
# EXTRACCIÓN Y LIMPIEZA
# def extract_text(element):
#     return element.text.strip() if element.text else ''
#
# narrativas = []
# for elem in root.iter():
#     txt = extract_text(elem)
#     if len(txt) > 20: # Filtrar nodos de texto cortos o basura
#         narrativas.append(txt)
# print(f'Segmentos extraidos: {len(narrativas)}')

# %%
# DISTRIBUCIONES
# longitudes = [len(n.split()) for n in narrativas]
# plt.hist(longitudes, bins=20)
# plt.title('Distribución de longitud (Tokens)')
# plt.show()
