# %% [markdown]
# # EDA: Componente de Visión (Whole Slide Images)
#
# This notebook is autogenerated as a boilerplate for Data Exploration (EDA).

# %%
# !pip install -q openslide-python
import sys
import os
from pathlib import Path
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    repo_root = '/content/clinical_core'
else:
    repo_root = os.path.abspath(os.path.join(os.getcwd(), '../../../../..'))
sys.path.append(os.path.join(repo_root, 'code'))
print('✅ Entorno EDA de Visión Configurado.')

# %%
import matplotlib.pyplot as plt
import numpy as np
try:
    import openslide
    print('Openslide importado correctamente')
except ImportError as e:
    print(f'Error importando openslide: {e}')

# %%
# CARGA DE DATOS (SVS Whole Slide Images)
# wsin_path = '/content/drive/MyDrive/data_tesis/slideimage/ejemplo.svs'
# slide = openslide.OpenSlide(wsin_path)
# print('Dimensiones Originales Nivel 0:', slide.dimensions)
# print('Niveles en la pirámide:', slide.level_count)

# %%
# EXTRACCIÓN DE PARCHES Y FILTRADO
# patch = slide.read_region((0, 0), level=2, size=(256, 256)).convert('RGB')
# plt.imshow(patch)
# plt.title('Parche de Muestra')
# plt.show()
